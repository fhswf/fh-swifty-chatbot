# %%
from langchain_mcp_adapters.client import MultiServerMCPClient
from chainlit.mcp import McpConnection, HttpMcpConnection

# %%
client = MultiServerMCPClient(
    {
        "fh-swf": {
            "url": "https://mcp.fh-swf.cloud/mcp",
            "transport": "streamable_http",
        }
    }
)
tools = await client.get_tools()
# Out:
# 2025-11-09 14:06:51 - HTTP Request: POST https://mcp.fh-swf.cloud/mcp "HTTP/1.1 200 OK"
# 2025-11-09 14:06:51 - Negotiated protocol version: 2025-06-18
# 2025-11-09 14:06:51 - HTTP Request: POST https://mcp.fh-swf.cloud/mcp "HTTP/1.1 202 Accepted"
# 2025-11-09 14:06:51 - HTTP Request: POST https://mcp.fh-swf.cloud/mcp "HTTP/1.1 200 OK"

# %%
tools[0]
# Out:
# StructuredTool(name='mensa_speiseplan_handler', args_schema={'properties': {'datum': {'type': 'string'}, 'location': {'type': 'string'}}, 'required': ['datum', 'location'], 'type': 'object'}, metadata={'_meta': {'_fastmcp': {'tags': []}}}, response_format='content_and_artifact', coroutine=<function convert_mcp_tool_to_langchain_tool.<locals>.call_tool at 0x1154ef380>)
