# %%
from docling.document_converter import DocumentConverter

# %%
source = "downloaded/data/www.fh-swf.de/media/neu_np/hv_2/downloads_der_studiengangsseiten/fb_tbw/wrvm/1_AO_2008_MA_wb_VB_WR.pdf"  # document per local path or URL
converter = DocumentConverter()
converter.format_to_options['pdf'].pipeline_options.do_ocr = False

# %%
result = converter.convert(source)
print(result.document.export_to_markdown())
# Out:
# 2025-10-06 12:46:40,471 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-06 12:46:40,472 - INFO - Going to convert document batch...
# 2025-10-06 12:46:40,473 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 60c8066c482b9239b869b997da3fb1da
# 2025-10-06 12:46:40,473 - INFO - Accelerator device: 'mps'
# 2025-10-06 12:46:42,061 - INFO - Accelerator device: 'mps'
# 2025-10-06 12:46:42,450 - INFO - Processing document 1_AO_2008_MA_wb_VB_WR.pdf
# 2025-10-06 12:46:44,601 - INFO - Finished converting document 1_AO_2008_MA_wb_VB_WR.pdf in 4.13 sec.
# ## Ordnung
#
# ## zur ˜nderung der Masterprüfungsordnung für den weiterbildenden Verbundstudiengang Wirtschaftsrecht an der Fachhochschule Südwestfalen, Standort Hagen, an der Fachhochschule Bielefeld und an der Hochschule Niederrhein in Mönchengladbach
#
# vom 24. Juli 2012
#
# ...

# %%
converter.format_to_options['pdf'].pipeline_options.__dict__
# Out:
# {'document_timeout': None,
#  'accelerator_options': AcceleratorOptions(num_threads=4, device='auto', cuda_use_flash_attention2=False),
#  'enable_remote_services': False,
#  'allow_external_plugins': False,
#  'artifacts_path': None,
#  'do_picture_classification': False,
#  'do_picture_description': False,
#  'picture_description_options': PictureDescriptionVlmOptions(batch_size=8, scale=2, picture_area_threshold=0.05, repo_id='HuggingFaceTB/SmolVLM-256M-Instruct', prompt='Describe this image in a few sentences.', generation_config={'max_new_tokens': 200, 'do_sample': False}),
#  'images_scale': 1.0,
#  'generate_page_images': False,
#  'generate_picture_images': False,
#  'do_table_structure': True,
#  'do_ocr': False,
#  'do_code_enrichment': False,
#  'do_formula_enrichment': False,
#  'force_backend_text': False,
#  'table_structure_options': TableStructureOptions(do_cell_matching=True, mode=<TableFormerMode.ACCURATE: 'accurate'>),
# ...
