# %%
import pymupdf4llm
from pathlib import Path

# %%
file_path = "s43681-022-00200-5.pdf"
markdown_content = pymupdf4llm.to_markdown(file_path)

# %%
Path(file_path).with_suffix('.md').write_text(markdown_content)
# Out:
# 71873
